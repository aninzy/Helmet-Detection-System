# %% [markdown]
# # Helmet Detection - Faster R-CNN ResNet50 V1 640x640:

# %% [markdown]
# ## 1. DOWNLOAD THE PRETRAINED MODELS FROM THE TENSORFLOW MODEL ZOO

# %%
import os

# DATA_DIR = os.path.join(os.getcwd(), 'data')
MODELS_DIR = os.path.join('pre-trained-model')
for dir in [MODELS_DIR]:
    if not os.path.exists(dir):
        os.mkdir(dir)

# %%
main_directory = 'models'
subfolder_name = 'faster_rcnn_resnet50_v1_640x640' #Change

main_directory_path = os.path.join(os.getcwd(), main_directory)
subfolder_path = os.path.join(main_directory_path, subfolder_name)

if not os.path.exists(subfolder_path):
    os.makedirs(subfolder_path)

# %%
import tarfile
import urllib.request
import os

# Download and extract model
MODEL_DATE = '20200711' #Change
MODEL_NAME = 'faster_rcnn_resnet50_v1_640x640_coco17_tpu-8' #Change
MODEL_TAR_FILENAME = MODEL_NAME + '.tar.gz'
MODELS_DOWNLOAD_BASE = 'http://download.tensorflow.org/models/object_detection/tf2/'
MODEL_DOWNLOAD_LINK = MODELS_DOWNLOAD_BASE + MODEL_DATE + '/' + MODEL_TAR_FILENAME
PATH_TO_MODEL_TAR = os.path.join(MODELS_DIR, MODEL_TAR_FILENAME)
PATH_TO_CKPT = os.path.join(MODELS_DIR, os.path.join(MODEL_NAME, 'checkpoint/'))
PATH_TO_CFG = os.path.join(MODELS_DIR, os.path.join(MODEL_NAME, 'pipeline.config'))
if not os.path.exists(PATH_TO_CKPT):
    print('Downloading model. This may take a while... ', end='')
    urllib.request.urlretrieve(MODEL_DOWNLOAD_LINK, PATH_TO_MODEL_TAR)
    tar_file = tarfile.open(PATH_TO_MODEL_TAR)
    tar_file.extractall(MODELS_DIR)
    tar_file.close()
    os.remove(PATH_TO_MODEL_TAR)
    print('Done')
# Out:
# Downloading model. This may take a while... Done

# %% [markdown]
# ## 2. SETUP PATHS:

# %%
WORKSPACE_PATH = '../training_helper_directory'
SCRIPT_PATH = WORKSPACE_PATH + '/scripts'
ANNOTATION_PATH = WORKSPACE_PATH + '/annotations'

IMAGE_PATH = '../Dataset/"PASCAL VOC Format Dataset"'

CUSTOM_MODEL_NAME = '/faster_rcnn_resnet50_v1_640x640' #Change: same as subfolder name
MODEL_PATH = './models' + CUSTOM_MODEL_NAME

PRETRAINED_PATH = './pre-trained-model/' + MODEL_NAME
CONFIG_PATH = MODEL_PATH + '/pipeline.config'

EXPORT_PATH = '../exported-models/my-model'

# %% [markdown]
# ## 3. CREATE TF RECORDS:

# %%
# Create train data:
# !python {SCRIPT_PATH + '/generate_tfrecord.py'} -x {IMAGE_PATH + '/train'} -l {ANNOTATION_PATH + '/label_map.pbtxt'} -o {ANNOTATION_PATH + '/train.record'}

# Create test data:
# !python {SCRIPT_PATH + '/generate_tfrecord.py'} -x {IMAGE_PATH + '/test'} -l {ANNOTATION_PATH + '/label_map.pbtxt'} -o {ANNOTATION_PATH + '/test.record'}
# Out:
# Successfully created the TFRecord file: ../training_helper_directory/annotations/train.record
# Successfully created the TFRecord file: ../training_helper_directory/annotations/test.record

# %% [markdown]
# ## 4. COPY MODEL CONFIG FILE TO TRANING FOLDER:

# %%
SOURCE_PATH = "D:\\Helmet Detection System\\Faster RCNN ResNet50 V1 640x640\\pre-trained-model\\faster_rcnn_resnet50_v1_640x640_coco17_tpu-8\\pipeline.config" #Change
DESTINATION_PATH = "D:\\Helmet Detection System\\Faster RCNN ResNet50 V1 640x640\models\\faster_rcnn_resnet50_v1_640x640" #Change

# %%
# !copy "{SOURCE_PATH}" "{DESTINATION_PATH}"
# Out:
#         1 file(s) copied.

# %% [markdown]
# ## 5. UPDATING CONFIG FOR TRANSFER LEARNING:

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# %%
config = config_util.get_configs_from_pipeline_file(CONFIG_PATH)

# %%
config
# Out:
# {'model': faster_rcnn {
#    num_classes: 90
#    image_resizer {
#      keep_aspect_ratio_resizer {
#        min_dimension: 640
#        max_dimension: 640
#        pad_to_max_dimension: true
#      }
#    }
#    feature_extractor {
#      type: "faster_rcnn_resnet50_keras"
#      batch_norm_trainable: true
#    }
#    first_stage_anchor_generator {
#      grid_anchor_generator {
#        height_stride: 16
#        width_stride: 16
#        scales: 0.25
#        scales: 0.5
#        scales: 1.0
#        scales: 2.0
#        aspect_ratios: 0.5
#        aspect_ratios: 1.0
#        aspect_ratios: 2.0
#      }
#    }
#    first_stage_box_predictor_conv_hyperparams {
#      op: CONV
#      regularizer {
#        l2_regularizer {
#          weight: 0.0
#        }
#      }
#      initializer {
#        truncated_normal_initializer {
#          stddev: 0.009999999776482582
#        }
#      }
#    }
#    first_stage_nms_score_threshold: 0.0
#    first_stage_nms_iou_threshold: 0.699999988079071
#    first_stage_max_proposals: 300
#    first_stage_localization_loss_weight: 2.0
#    first_stage_objectness_loss_weight: 1.0
#    initial_crop_size: 14
#    maxpool_kernel_size: 2
#    maxpool_stride: 2
#    second_stage_box_predictor {
#      mask_rcnn_box_predictor {
#        fc_hyperparams {
#          op: FC
#          regularizer {
#            l2_regularizer {
#              weight: 0.0
#            }
#          }
#          initializer {
#            variance_scaling_initializer {
#              factor: 1.0
#              uniform: true
#              mode: FAN_AVG
#            }
#          }
#        }
#        use_dropout: false
#        dropout_keep_probability: 1.0
#        share_box_across_classes: true
#      }
#    }
#    second_stage_post_processing {
#      batch_non_max_suppression {
#        score_threshold: 0.0
#        iou_threshold: 0.6000000238418579
#        max_detections_per_class: 100
#        max_total_detections: 300
#      }
#      score_converter: SOFTMAX
#    }
#    second_stage_localization_loss_weight: 2.0
#    second_stage_classification_loss_weight: 1.0
#    use_matmul_crop_and_resize: true
#    clip_anchors_to_image: true
#    use_matmul_gather_in_matcher: true
#    use_static_balanced_label_sampler: true
#    use_static_shapes: true
#  },
#  'train_config': batch_size: 64
#  data_augmentation_options {
#    random_horizontal_flip {
#    }
#  }
#  sync_replicas: true
#  optimizer {
#    momentum_optimizer {
#      learning_rate {
#        cosine_decay_learning_rate {
#          learning_rate_base: 0.03999999910593033
#          total_steps: 25000
#          warmup_learning_rate: 0.013333000242710114
#          warmup_steps: 2000
#        }
#      }
#      momentum_optimizer_value: 0.8999999761581421
#    }
#    use_moving_average: false
#  }
#  fine_tune_checkpoint: "PATH_TO_BE_CONFIGURED"
#  num_steps: 25000
#  startup_delay_steps: 0.0
#  replicas_to_aggregate: 8
#  max_number_of_boxes: 100
#  unpad_groundtruth_tensors: false
#  fine_tune_checkpoint_type: "classification"
#  use_bfloat16: true
#  fine_tune_checkpoint_version: V2,
#  'train_input_config': label_map_path: "PATH_TO_BE_CONFIGURED/label_map.txt"
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED/train2017-?????-of-00256.tfrecord"
#  },
#  'eval_config': metrics_set: "coco_detection_metrics"
#  use_moving_averages: false
#  batch_size: 1,
#  'eval_input_configs': [label_map_path: "PATH_TO_BE_CONFIGURED/label_map.txt"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED/val2017-?????-of-00032.tfrecord"
#  }
#  ],
#  'eval_input_config': label_map_path: "PATH_TO_BE_CONFIGURED/label_map.txt"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED/val2017-?????-of-00032.tfrecord"
#  }}

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(CONFIG_PATH, "r") as f:
    proto_str = f.read()
    text_format.Merge(proto_str, pipeline_config)

# %%
pipeline_config.model.faster_rcnn.num_classes = 2 #Change

pipeline_config.train_config.batch_size = 1 #Change
pipeline_config.train_config.num_steps = 1000 #Change
pipeline_config.train_config.use_bfloat16 = False

pipeline_config.train_config.fine_tune_checkpoint = PRETRAINED_PATH + '/checkpoint/ckpt-0'
pipeline_config.train_config.fine_tune_checkpoint_type = "detection" 

pipeline_config.train_input_reader.label_map_path = ANNOTATION_PATH + '/label_map.pbtxt'
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [ANNOTATION_PATH+ '/train.record'] 

pipeline_config.eval_input_reader[0].label_map_path = ANNOTATION_PATH + '/label_map.pbtxt'
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [ANNOTATION_PATH + '/test.record']

# %%
config_text = text_format.MessageToString(pipeline_config)
with tf.io.gfile.GFile(CONFIG_PATH, "wb") as f:
    f.write(config_text)

# %% [markdown]
# ## 6. TRAIN THE MODEL:

# %%
import tensorflow as tf
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import os
os.getcwd()
# Out:
# 'd:\\Helmet Detection System\\Faster RCNN ResNet50 V1 640x640'

# %%
# !python {SCRIPT_PATH + '/model_main_tf2.py'} --model_dir={MODEL_PATH} --pipeline_config_path={MODEL_PATH + '/pipeline.config'}
# Out:
# 2024-03-10 16:39:22.426566: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-10 16:39:22.808670: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1656 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0310 16:39:22.868163 45148 mirrored_strategy.py:374] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: None
# I0310 16:39:22.875199 45148 config_util.py:552] Maybe overwriting train_steps: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0310 16:39:22.876214 45148 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From c:\Users\sudee\.conda\envs\helmet\lib\site-packages\object_detection\model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W0310 16:39:22.897268 45148 deprecation.py:350] From c:\Users\sudee\.conda\envs\helmet\lib\site-packages\object_detection\model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['../training_helper_directory/annotations/train.record']
# I0310 16:39:22.900268 45148 dataset_builder.py:162] Reading unweighted datasets: ['../training_helper_directory/annotations/train.record']
# INFO:tensorflow:Reading record datasets for input file: ['../training_helper_directory/annotations/train.record']
# I0310 16:39:22.900268 45148 dataset_builder.py:79] Reading record datasets for input file: ['../training_helper_directory/annotations/train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0310 16:39:22.900268 45148 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0310 16:39:22.900268 45148 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From c:\Users\sudee\.conda\envs\helmet\lib\site-packages\object_detection\builders\dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0310 16:39:22.902268 45148 deprecation.py:350] From c:\Users\sudee\.conda\envs\helmet\lib\site-packages\object_detection\builders\dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From c:\Users\sudee\.conda\envs\helmet\lib\site-packages\object_detection\builders\dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0310 16:39:22.918267 45148 deprecation.py:350] From c:\Users\sudee\.conda\envs\helmet\lib\site-packages\object_detection\builders\dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From c:\Users\sudee\.conda\envs\helmet\lib\site-packages\tensorflow\python\util\dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0310 16:39:26.902013 45148 deprecation.py:350] From c:\Users\sudee\.conda\envs\helmet\lib\site-packages\tensorflow\python\util\dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From c:\Users\sudee\.conda\envs\helmet\lib\site-packages\tensorflow\python\util\dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0310 16:39:28.639625 45148 deprecation.py:350] From c:\Users\sudee\.conda\envs\helmet\lib\site-packages\tensorflow\python\util\dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# c:\Users\sudee\.conda\envs\helmet\lib\site-packages\keras\backend.py:450: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0310 16:39:34.111185 13884 convolutional_keras_box_predictor.py:152] depth of additional conv before box predictor: 0
# WARNING:tensorflow:From c:\Users\sudee\.conda\envs\helmet\lib\site-packages\tensorflow\python\autograph\impl\api.py:459: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# W0310 16:39:38.670180 13884 deprecation.py:350] From c:\Users\sudee\.conda\envs\helmet\lib\site-packages\tensorflow\python\autograph\impl\api.py:459: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# WARNING:tensorflow:From c:\Users\sudee\.conda\envs\helmet\lib\site-packages\tensorflow\python\util\dispatch.py:1082: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# W0310 16:39:41.716870 13884 deprecation.py:350] From c:\Users\sudee\.conda\envs\helmet\lib\site-packages\tensorflow\python\util\dispatch.py:1082: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# 2024-03-10 16:39:46.652213: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8907
# 2024-03-10 16:39:48.162051: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-10 16:39:48.162507: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-10 16:39:48.197275: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-10 16:39:48.197834: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-10 16:39:48.673907: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-10 16:39:48.674347: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-10 16:39:48.728308: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2024-03-10 16:39:48.822708: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.09GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-10 16:39:48.823143: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.09GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-10 16:39:48.937073: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.15GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-10 16:39:48.937483: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.15GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-10 16:39:59.128286: W tensorflow/core/common_runtime/bfc_allocator.cc:479] Allocator (GPU_0_bfc) ran out of memory trying to allocate 918.75MiB (rounded to 963379200)requested by op MultiLevelMatMulCropAndResize/MultiLevelRoIAlign/AvgPool-0-TransposeNHWCToNCHW-LayoutOptimizer
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2024-03-10 16:39:59.129017: I tensorflow/core/common_runtime/bfc_allocator.cc:1027] BFCAllocator dump for GPU_0_bfc
# 2024-03-10 16:39:59.129175: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (256): 	Total Chunks: 109, Chunks in use: 109. 27.2KiB allocated for chunks. 27.2KiB in use in bin. 8.2KiB client-requested in use in bin.
# 2024-03-10 16:39:59.129460: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (512): 	Total Chunks: 36, Chunks in use: 36. 18.2KiB allocated for chunks. 18.2KiB in use in bin. 17.6KiB client-requested in use in bin.
# 2024-03-10 16:39:59.129754: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (1024): 	Total Chunks: 77, Chunks in use: 73. 81.8KiB allocated for chunks. 76.0KiB in use in bin. 74.0KiB client-requested in use in bin.
# 2024-03-10 16:39:59.130048: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (2048): 	Total Chunks: 48, Chunks in use: 46. 99.8KiB allocated for chunks. 93.8KiB in use in bin. 93.5KiB client-requested in use in bin.
# 2024-03-10 16:39:59.130351: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (4096): 	Total Chunks: 35, Chunks in use: 34. 149.8KiB allocated for chunks. 144.8KiB in use in bin. 139.4KiB client-requested in use in bin.
# 2024-03-10 16:39:59.130642: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (8192): 	Total Chunks: 16, Chunks in use: 16. 135.5KiB allocated for chunks. 135.5KiB in use in bin. 128.0KiB client-requested in use in bin.
# 2024-03-10 16:39:59.130943: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (16384): 	Total Chunks: 1, Chunks in use: 1. 28.0KiB allocated for chunks. 28.0KiB in use in bin. 16.0KiB client-requested in use in bin.
# 2024-03-10 16:39:59.131224: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (32768): 	Total Chunks: 4, Chunks in use: 4. 160.5KiB allocated for chunks. 160.5KiB in use in bin. 140.8KiB client-requested in use in bin.
# 2024-03-10 16:39:59.131513: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (65536): 	Total Chunks: 8, Chunks in use: 7. 611.2KiB allocated for chunks. 533.2KiB in use in bin. 501.2KiB client-requested in use in bin.
# 2024-03-10 16:39:59.131798: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (131072): 	Total Chunks: 8, Chunks in use: 6. 1.34MiB allocated for chunks. 945.0KiB in use in bin. 806.0KiB client-requested in use in bin.
# 2024-03-10 16:39:59.132080: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (262144): 	Total Chunks: 10, Chunks in use: 10. 2.92MiB allocated for chunks. 2.92MiB in use in bin. 2.63MiB client-requested in use in bin.
# 2024-03-10 16:39:59.132389: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (524288): 	Total Chunks: 8, Chunks in use: 6. 4.26MiB allocated for chunks. 3.25MiB in use in bin. 3.25MiB client-requested in use in bin.
# 2024-03-10 16:39:59.132686: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (1048576): 	Total Chunks: 15, Chunks in use: 13. 16.38MiB allocated for chunks. 14.00MiB in use in bin. 13.00MiB client-requested in use in bin.
# 2024-03-10 16:39:59.132995: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (2097152): 	Total Chunks: 9, Chunks in use: 8. 21.00MiB allocated for chunks. 17.50MiB in use in bin. 17.50MiB client-requested in use in bin.
# 2024-03-10 16:39:59.133295: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (4194304): 	Total Chunks: 11, Chunks in use: 8. 51.19MiB allocated for chunks. 34.94MiB in use in bin. 34.06MiB client-requested in use in bin.
# 2024-03-10 16:39:59.133595: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (8388608): 	Total Chunks: 5, Chunks in use: 5. 49.00MiB allocated for chunks. 49.00MiB in use in bin. 42.32MiB client-requested in use in bin.
# 2024-03-10 16:39:59.133889: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (16777216): 	Total Chunks: 2, Chunks in use: 1. 41.50MiB allocated for chunks. 18.00MiB in use in bin. 18.00MiB client-requested in use in bin.
# 2024-03-10 16:39:59.134196: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-03-10 16:39:59.134459: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-03-10 16:39:59.134770: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-03-10 16:39:59.135110: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (268435456): 	Total Chunks: 2, Chunks in use: 1. 1.43GiB allocated for chunks. 918.75MiB in use in bin. 918.75MiB client-requested in use in bin.
# 2024-03-10 16:39:59.135448: I tensorflow/core/common_runtime/bfc_allocator.cc:1050] Bin for 918.75MiB was 256.00MiB, Chunk State:
# 2024-03-10 16:39:59.135628: I tensorflow/core/common_runtime/bfc_allocator.cc:1056]   Size: 548.83MiB | Requested Size: 8.2KiB | in_use: 0 | bin_num: 20, prev:   Size: 918.75MiB | Requested Size: 918.75MiB | in_use: 1 | bin_num: -1
# 2024-03-10 16:39:59.135904: I tensorflow/core/common_runtime/bfc_allocator.cc:1063] Next region of size 1736913664
# 2024-03-10 16:39:59.136630: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 70b800000 of size 256 next 1
# 2024-03-10 16:39:59.136776: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 70b800100 of size 1280 next 2
# 2024-03-10 16:39:59.136924: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 70b800600 of size 256 next 3
# 2024-03-10 16:39:59.137072: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 70b800700 of size 256 next 4
# 2024-03-10 16:39:59.137217: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 70b800800 of size 256 next 5
# 2024-03-10 16:39:59.137367: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 70b800900 of size 256 next 6
# 2024-03-10 16:39:59.137517: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 70b800a00 of size 4915200 next 7
# 2024-03-10 16:39:59.137667: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 70bcb0a00 of size 256 next 8
# 2024-03-10 16:39:59.137817: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 70bcb0b00 of size 256 next 9
# 2024-03-10 16:39:59.137955: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 70bcb0c00 of size 512 next 10
# 2024-03-10 16:39:59.138099: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 70bcb0e00 of size 1792 next 11
# 2024-03-10 16:39:59.138253: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 70bcb1500 of size 1024 next 12
# 2024-03-10 16:39:59.138396: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 70bcb1900 of size 1024 next 13
# 2024-03-10 16:39:59.138543: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 70bc
I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 4 Chunks of size 1310720 totalling 5.00MiB
# 2024-03-10 16:39:59.210403: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 2 Chunks of size 2097152 totalling 4.00MiB
# 2024-03-10 16:39:59.210580: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 6 Chunks of size 2359296 totalling 13.50MiB
# 2024-03-10 16:39:59.210784: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 6 Chunks of size 4194304 totalling 24.00MiB
# 2024-03-10 16:39:59.210991: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 4915200 totalling 4.69MiB
# 2024-03-10 16:39:59.211146: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 6553600 totalling 6.25MiB
# 2024-03-10 16:39:59.211355: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 8388608 totalling 8.00MiB
# 2024-03-10 16:39:59.211524: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 3 Chunks of size 9437184 totalling 27.00MiB
# 2024-03-10 16:39:59.211709: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 14680064 totalling 14.00MiB
# 2024-03-10 16:39:59.211890: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 18874368 totalling 18.00MiB
# 2024-03-10 16:39:59.212072: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 963379200 totalling 918.75MiB
# 2024-03-10 16:39:59.212260: I tensorflow/core/common_runtime/bfc_allocator.cc:1095] Sum Total of in-use chunks: 1.04GiB
# 2024-03-10 16:39:59.212462: I tensorflow/core/common_runtime/bfc_allocator.cc:1097] total_region_allocated_bytes_: 1736913664 memory_limit_: 1736913716 available bytes: 52 curr_region_allocation_bytes_: 3473827840
# 2024-03-10 16:39:59.212804: I tensorflow/core/common_runtime/bfc_allocator.cc:1103] Stats:
# Limit:                      1736913716
# InUse:                      1111979264
# MaxInUse:                   1121031424
# NumAllocs:                        1472
# MaxAllocSize:                963379200
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2024-03-10 16:39:59.213359: W tensorflow/core/common_runtime/bfc_allocator.cc:491] *********_*********************************************************_________________________________
# 2024-03-10 16:39:59.213639: W tensorflow/core/framework/op_kernel.cc:1745] OP_REQUIRES failed at transpose_op.cc:183 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[300,1024,28,28] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# Traceback (most recent call last):
#   File "d:\Helmet Detection System\training_helper_directory\scripts\model_main_tf2.py", line 113, in <module>
#     tf.compat.v1.app.run()
#   File "c:\Users\sudee\.conda\envs\helmet\lib\site-packages\tensorflow\python\platform\app.py", line 36, in run
#     _run(main=main, argv=argv, flags_parser=_parse_flags_tolerate_undef)
#   File "c:\Users\sudee\.conda\envs\helmet\lib\site-packages\absl\app.py", line 308, in run
#     _run_main(main, args)
#   File "c:\Users\sudee\.conda\envs\helmet\lib\site-packages\absl\app.py", line 254, in _run_main
#     sys.exit(main(argv))
#   File "d:\Helmet Detection System\training_helper_directory\scripts\model_main_tf2.py", line 104, in main
#     model_lib_v2.train_loop(
#   File "c:\Users\sudee\.conda\envs\helmet\lib\site-packages\object_detection\model_lib_v2.py", line 605, in train_loop
#     load_fine_tune_checkpoint(
#   File "c:\Users\sudee\.conda\envs\helmet\lib\site-packages\object_detection\model_lib_v2.py", line 401, in load_fine_tune_checkpoint
#     _ensure_model_is_built(model, input_dataset, unpad_groundtruth_tensors)
#   File "c:\Users\sudee\.conda\envs\helmet\lib\site-packages\object_detection\model_lib_v2.py", line 176, in _ensure_model_is_built
#     strategy.run(
#   File "c:\Users\sudee\.conda\envs\helmet\lib\site-packages\tensorflow\python\distribute\distribute_lib.py", line 1312, in run
#     return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#   File "c:\Users\sudee\.conda\envs\helmet\lib\site-packages\tensorflow\python\distribute\distribute_lib.py", line 2888, in call_for_each_replica
#     return self._call_for_each_replica(fn, args, kwargs)
#   File "c:\Users\sudee\.conda\envs\helmet\lib\site-packages\tensorflow\python\distribute\mirrored_strategy.py", line 676, in _call_for_each_replica
#     return mirrored_run.call_for_each_replica(
#   File "c:\Users\sudee\.conda\envs\helmet\lib\site-packages\tensorflow\python\distribute\mirrored_run.py", line 83, in call_for_each_replica
#     return wrapped(args, kwargs)
#   File "c:\Users\sudee\.conda\envs\helmet\lib\site-packages\tensorflow\python\util\traceback_utils.py", line 153, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "c:\Users\sudee\.conda\envs\helmet\lib\site-packages\tensorflow\python\eager\execute.py", line 54, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# tensorflow.python.framework.errors_impl.ResourceExhaustedError: Graph execution error:
#
# OOM when allocating tensor with shape[300,1024,28,28] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node MultiLevelMatMulCropAndResize/MultiLevelRoIAlign/AvgPool-0-TransposeNHWCToNCHW-LayoutOptimizer}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference__dummy_computation_fn_13457]

# %%
# !python {SCRIPT_PATH + '/exporter_main_v2.py'} --input_type image_tensor --pipeline_config_path {CONFIG_PATH} --trained_checkpoint_dir {MODEL_PATH + '/' } --output_directory exported-models\my-model
# Out:
# 2024-03-10 16:40:04.772087: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-10 16:40:05.121086: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1656 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# WARNING:tensorflow:From c:\Users\sudee\.conda\envs\helmet\lib\site-packages\tensorflow\python\autograph\impl\api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W0310 16:40:05.258622 37972 deprecation.py:623] From c:\Users\sudee\.conda\envs\helmet\lib\site-packages\tensorflow\python\autograph\impl\api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0310 16:40:07.811411 37972 convolutional_keras_box_predictor.py:152] depth of additional conv before box predictor: 0
# WARNING:tensorflow:From c:\Users\sudee\.conda\envs\helmet\lib\site-packages\tensorflow\python\autograph\impl\api.py:459: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# W0310 16:40:14.921795 37972 deprecation.py:350] From c:\Users\sudee\.conda\envs\helmet\lib\site-packages\tensorflow\python\autograph\impl\api.py:459: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# Traceback (most recent call last):
#   File "d:\Helmet Detection System\training_helper_directory\scripts\exporter_main_v2.py", line 159, in <module>
#     app.run(main)
#   File "c:\Users\sudee\.conda\envs\helmet\lib\site-packages\absl\app.py", line 308, in run
#     _run_main(main, args)
#   File "c:\Users\sudee\.conda\envs\helmet\lib\site-packages\absl\app.py", line 254, in _run_main
#     sys.exit(main(argv))
#   File "d:\Helmet Detection System\training_helper_directory\scripts\exporter_main_v2.py", line 152, in main
#     exporter_lib_v2.export_inference_graph(
#   File "c:\Users\sudee\.conda\envs\helmet\lib\site-packages\object_detection\exporter_lib_v2.py", line 271, in export_inference_graph
#     status.assert_existing_objects_matched()
#   File "c:\Users\sudee\.conda\envs\helmet\lib\site-packages\tensorflow\python\training\tracking\util.py", line 948, in assert_existing_objects_matched
#     raise AssertionError(
# AssertionError: No checkpoint specified (save_path=None); nothing is being restored.

# %% [markdown]
# Inferencing My Trained Models

# %%
"""
Object Detection (On Image) From TF2 Saved Model
=====================================
"""

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'    # Suppress TensorFlow logging (1)
import pathlib
import tensorflow as tf
import cv2
import argparse
# from google.colab.patches import cv2_imshow

# Enable GPU dynamic memory allocation
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# PROVIDE PATH TO IMAGE DIRECTORY
IMAGE_PATHS = 'D:/Helmet Detection System/Dataset/PASCAL VOC Format Dataset/test/BikesHelmets392_png.rf.9802b10c090e222ccda1a9c575875961.jpg' #Change


# PROVIDE PATH TO MODEL DIRECTORY
PATH_TO_MODEL_DIR = './exported-models/my-model'

# PROVIDE PATH TO LABEL MAP
PATH_TO_LABELS = ANNOTATION_PATH + '/label_map.pbtxt'

# PROVIDE THE MINIMUM CONFIDENCE THRESHOLD
MIN_CONF_THRESH = float(0.60)

# LOAD THE MODEL

import time
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils

PATH_TO_SAVED_MODEL = PATH_TO_MODEL_DIR + "/saved_model"

print('Loading model...', end='')
start_time = time.time()

# LOAD SAVED MODEL AND BUILD DETECTION FUNCTION
detect_fn = tf.saved_model.load(PATH_TO_SAVED_MODEL)

end_time = time.time()
elapsed_time = end_time - start_time
print('Done! Took {} seconds'.format(elapsed_time))

# LOAD LABEL MAP DATA FOR PLOTTING

category_index = label_map_util.create_category_index_from_labelmap(PATH_TO_LABELS,
                                                                    use_display_name=True)

import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')   # Suppress Matplotlib warnings

def load_image_into_numpy_array(path):
    """Load an image from file into a numpy array.
    Puts image into numpy array to feed into tensorflow graph.
    Note that by convention we put it into a numpy array with shape
    (height, width, channels), where channels=3 for RGB.
    Args:
      path: the file path to the image
    Returns:
      uint8 numpy array with shape (img_height, img_width, 3)
    """
    return np.array(Image.open(path))

print('Running inference for {}... '.format(IMAGE_PATHS), end='')

image = cv2.imread(IMAGE_PATHS)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image_expanded = np.expand_dims(image_rgb, axis=0)

# The input needs to be a tensor, convert it using `tf.convert_to_tensor`.
input_tensor = tf.convert_to_tensor(image)
# The model expects a batch of images, so add an axis with `tf.newaxis`.
input_tensor = input_tensor[tf.newaxis, ...]

# input_tensor = np.expand_dims(image_np, 0)
detections = detect_fn(input_tensor)

# All outputs are batches tensors.
# Convert to numpy arrays, and take index [0] to remove the batch dimension.
# We're only interested in the first num_detections.
num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy()
               for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

image_with_detections = image.copy()

# SET MIN_SCORE_THRESH BASED ON YOU MINIMUM THRESHOLD FOR DETECTIONS
viz_utils.visualize_boxes_and_labels_on_image_array(
      image_with_detections,
      detections['detection_boxes'],
      detections['detection_classes'],
      detections['detection_scores'],
      category_index,
      use_normalized_coordinates=True,
      max_boxes_to_draw=100,
      min_score_thresh=0.5,
      agnostic_mode=False)

print('Done')
# DISPLAYS OUTPUT IMAGE
cv2.imshow('test', image_with_detections)
# CLOSES WINDOW ONCE KEY IS PRESSED
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Loading model...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[18], line 44
#      41 start_time = time.time()
#      43 # LOAD SAVED MODEL AND BUILD DETECTION FUNCTION
# ---> 44 detect_fn = tf.saved_model.load(PATH_TO_SAVED_MODEL)
#      46 end_time = time.time()
#      47 elapsed_time = end_time - start_time
#
# File c:\Users\sudee\.conda\envs\helmet\lib\site-packages\tensorflow\python\saved_model\load.py:782, in load(export_dir, tags, options)
#     780 if isinstance(export_dir, os.PathLike):
#     781   export_dir = os.fspath(export_dir)
# --> 782 result = load_partial(export_dir, None, tags, options)["root"]
#     783 return result
#
# File c:\Users\sudee\.conda\envs\helmet\lib\site-packages\tensorflow\python\saved_model\load.py:887, in load_partial(export_dir, filters, tags, options)
#     882 if tags is not None and not isinstance(tags, set):
#     883   # Supports e.g. tags=SERVING and tags=[SERVING]. Sets aren't considered
#     884   # sequences for nest.flatten, so we put those through as-is.
#     885   tags = nest.flatten(tags)
#     886 saved_model_proto, debug_info = (
# --> 887     loader_impl.parse_saved_model_with_debug_info(export_dir))
#     889 if (len(saved_model_proto.meta_graphs) == 1 and
#     890     saved_model_proto.meta_graphs[0].HasField("object_graph_def")):
#     891   metrics.IncrementReadApi(_LOAD_V2_LABEL)
#
# File c:\Users\sudee\.conda\envs\helmet\lib\site-packages\tensorflow\python\saved_model\loader_impl.py:57, in parse_saved_model_with_debug_info(export_dir)
#      44 def parse_saved_model_with_debug_info(export_dir):
#      45   """Reads the savedmodel as well as the graph debug info.
#      46
#      47   Args:
#    (...)
#      55     parsed. Missing graph debug info file is fine.
#      56   """
# ---> 57   saved_model = parse_saved_model(export_dir)
#      59   debug_info_path = file_io.join(
#      60       saved_model_utils.get_debug_dir(export_dir),
#      61       constants.DEBUG_INFO_FILENAME_PB)
#      62   debug_info = graph_debug_info_pb2.GraphDebugInfo()
#
# File c:\Users\sudee\.conda\envs\helmet\lib\site-packages\tensorflow\python\saved_model\loader_impl.py:115, in parse_saved_model(export_dir)
#     113     raise IOError(f"Cannot parse file {path_to_pbtxt}: {str(e)}.")
#     114 else:
# --> 115   raise IOError(
#     116       f"SavedModel file does not exist at: {export_dir}{os.path.sep}"
#     117       f"{{{constants.SAVED_MODEL_FILENAME_PBTXT}|"
#     118       f"{constants.SAVED_MODEL_FILENAME_PB}}}")
#
# OSError: SavedModel file does not exist at: ./exported-models/my-model/saved_model\{saved_model.pbtxt|saved_model.pb}
